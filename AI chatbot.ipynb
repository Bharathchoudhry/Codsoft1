# %%
import re

# %%
def chatbot():

  print("Hi ! I'm a simple chatbot. How can I help you ?")


  while True:
    user_input = input("You: ")


    user_input = user_input.lower()


    if user_input == "bye":
      print("Chatbot: Bye! Have a nice day.")
      break


    elif "hi" in user_input or "hello" in user_input:
      print("Chatbot: Hi! How can I help you ?")

    elif "can i ask some question?" in user_input:
      print("chatbot : yes, you can ask ")

    elif  "ok" in user_input:
      print("chatbot: Go ahead and ask your question whenever you're ready.")

    elif "This is a cool chatbot" in user_input:
      print("chatbot: oh! thank u ")

    elif "I like the way you respond" in user_input:
        print("chatbot : oh! thank u")

    elif "how was u r day" in user_input:
        print("chatbot: My day has been good, thank you for asking. I've been here to help")

    elif "nothing" in user_input:
        print("chatbot: That's okay. Sometimes it's nice to have some downtime. Is there anything you'd like to talk about or any topic you're interested in discussing?")

    elif "shall we make a trip" in user_input:
         print("chatbot : I am here to provide information and assistance, so if you have any questions or need help planning a trip, feel free to ask!.")

    elif "i am good what about u"in user_input:
        print("chatbot: I'm here and ready to assist you with anything you need.")

    elif "go and sleep,shutdown the system"in user_input:
        print("chatbot: ok bye ,thanks for this opporunity")

    elif "if i pin the date u just remember" in user_input:
        print("chatbot : ok ,I will drop a msg")

    elif "what is the weather today" in user_input:
      print("Chatbot: soory, i cannot give real time information")

    # Respond to anything else
    else:
      print("Chatbot: Sorry, I don't  understand ")

if __name__ == "__main__":
  chatbot()
# Out:
# Hi ! I'm a simple chatbot. How can I help you ?
# You: hi
# Chatbot: Hi! How can I help you ?
# You: what is the weather today
# Chatbot: soory, i cannot give real time information
# You: ok
# chatbot: Go ahead and ask your question whenever you're ready.
# You: This is a cool chatbot
# Chatbot: Hi! How can I help you ?
# You: bye
# Chatbot: Bye! Have a nice day.
